# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Nikhil Margam
# Data Scientist

# %% [markdown]
# *string* I am interested in data science because i always been a problem solver and want to start my carreer in most demanding job in 2022.

# %% [markdown]
# ### code is supposed to add the 2 numeric values and display output

# %%
6+11
# Out:
# 17

# %% [markdown]
# -----
#  - hi
#  - bye
#  - good
#  - bad
# 1. name
# 2. dob
# 3. place
